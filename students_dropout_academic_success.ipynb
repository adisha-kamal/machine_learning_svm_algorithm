# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/DELL/Documents/machine_learning/svm/students_dropout_academic_success.csv')

# %%
df.head()
# Out:
#    Marital Status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# 2                           122.0            1                      37
# 3                           122.0            1                      38
# 4                           100.0            1                      37
#
#    Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 0                      12  ...                                    0
# 1                       3  ...                                    0
# 2                      37  ...                                    0
# 3                      37  ...                                    0
# 4                      38  ...                                    0
#
#    Curricular units 2nd sem (enrolled)  \
# 0                                    0
# 1                                    6
# 2                                    6
# 3                                    6
# 4                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                      10
# 4                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
# 3                                    5                         12.400000
# 4                                    6                         13.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
# 3                                               0                9.4
# 4                                               0               13.9
#
#    Inflation rate   GDP    target
# 0             1.4  1.74   Dropout
# 1            -0.3  0.79  Graduate
# 2             1.4  1.74   Dropout
# 3            -0.8 -3.12  Graduate
# 4            -0.3  0.79  Graduate
#
# [5 rows x 37 columns]

# %%
df.tail()
# Out:
#       Marital Status  Application mode  Application order  Course  \
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance  Previous qualification  \
# 4419                           1                       1
# 4420                           1                       1
# 4421                           1                       1
# 4422                           1                       1
# 4423                           1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 4419                           125.0            1                       1
# 4420                           120.0          105                       1
# 4421                           154.0            1                      37
# 4422                           180.0            1                      37
# 4423                           152.0           22                      38
#
#       Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 4419                       1  ...                                    0
# 4420                       1  ...                                    0
# 4421                      37  ...                                    0
# 4422                      37  ...                                    0
# 4423                      37  ...                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 4419                                    6
# 4420                                    6
# 4421                                    8
# 4422                                    5
# 4423                                    6
#
#       Curricular units 2nd sem (evaluations)  \
# 4419                                       8
# 4420                                       6
# 4421                                       9
# 4422                                       6
# 4423                                       6
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 4419                                    5                         12.666667
# 4420                                    2                         11.000000
# 4421                                    1                         13.500000
# 4422                                    5                         12.000000
# 4423                                    6                         13.000000
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 4419                                               0               15.5
# 4420                                               0               11.1
# 4421                                               0               13.9
# 4422                                               0                9.4
# 4423                                               0               12.7
#
#       Inflation rate   GDP    target
# 4419             2.8 -4.06  Graduate
# 4420             0.6  2.02   Dropout
# 4421            -0.3  0.79   Dropout
# 4422            -0.8 -3.12  Graduate
# 4423             3.7 -1.70  Graduate
#
# [5 rows x 37 columns]

# %%
df.shape
# Out:
# (4424, 37)

# %%
df.columns
# Out:
# Index(['Marital Status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
#        'Curricular units 2nd sem (without evaluations)', 'Unemployment rate',
#        'Inflation rate', 'GDP', 'target'],
#       dtype='object')

# %%
df1=df['target'].value_counts()
df1
# Out:
# target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %%
plt.bar(df1.index,df1.values)
# Out:
# <BarContainer object of 3 artists>

# %%
df.isna().sum()
# Out:
# Marital Status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# International                                     0
# Curricular units 1st sem (credited)               0
# Curricular units 1st sem (enrolled)               0
# Curricular units 1st sem (evaluations)            0
# Curricular units 1st sem (approved)               0
# Curricular units 1st sem (grade)                  0
# Curricular units 1st sem (without evaluations)    0
# Curricular units 2nd sem (credited)               0
# Curricular units 2nd sem (enrolled)               0
# Curricular units 2nd sem (evaluations)            0
# Curricular units 2nd sem (approved)               0
# Curricular units 2nd sem (grade)                  0
# Curricular units 2nd sem (without evaluations)    0
# Unemployment rate                                 0
# Inflation rate                                    0
# GDP                                               0
# target                                            0
# dtype: int64

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)
x_train
# Out:
#       Marital Status  Application mode  Application order  Course  \
# 1501               1                 1                  1    9670
# 2704               1                17                  1    9670
# 4283               1                39                  1    9147
# 1288               1                 1                  1    9773
# 137                1                 1                  1    9773
# ...              ...               ...                ...     ...
# 2895               2                 1                  1    8014
# 2763               1                43                  1    8014
# 905                1                 1                  3    9500
# 3980               1                17                  6    9238
# 235                1                 1                  1    9238
#
#       Daytime/evening attendance  Previous qualification  \
# 1501                           1                       1
# 2704                           1                       1
# 4283                           1                      19
# 1288                           1                       1
# 137                            1                       1
# ...                          ...                     ...
# 2895                           0                       1
# 2763                           0                       3
# 905                            1                       1
# 3980                           1                       1
# 235                            1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 1501                           126.0            1                       1
# 2704                           109.0            1                       1
# 4283                           100.0            1                      38
# 1288                           120.0            1                      36
# 137                            153.0            1                       1
# ...                              ...          ...                     ...
# 2895                           151.0            1                      37
# 2763                           133.1            1                       9
# 905                            114.0            1                       1
# 3980                           117.0            1                       1
# 235                            154.0            1                      38
#
#       Father's qualification  ...  \
# 1501                       1  ...
# 2704                       1  ...
# 4283                      19  ...
# 1288                      37  ...
# 137                        1  ...
# ...                      ...  ...
# 2895                      37  ...
# 2763                       9  ...
# 905                        1  ...
# 3980                      38  ...
# 235                       37  ...
#
#       Curricular units 1st sem (without evaluations)  \
# 1501                                               1
# 2704                                               0
# 4283                                               0
# 1288                                               0
# 137                                                0
# ...                                              ...
# 2895                                               0
# 2763                                               0
# 905                                                0
# 3980                                               0
# 235                                                0
#
#       Curricular units 2nd sem (credited)  \
# 1501                                    0
# 2704                                    0
# 4283                                    0
# 1288                                    0
# 137                                     0
# ...                                   ...
# 2895                                    0
# 2763                                    3
# 905                                     0
# 3980                                    0
# 235                                     0
#
#       Curricular units 2nd sem (enrolled)  \
# 1501                                    6
# 2704                                    5
# 4283                                    5
# 1288                                    6
# 137                                     6
# ...                                   ...
# 2895                                    6
# 2763                                    7
# 905                                     8
# 3980                                    6
# 235                                     6
#
#       Curricular units 2nd sem (evaluations)  \
# 1501                                       0
# 2704                                       5
# 4283                                       9
# 1288                                      11
# 137                                        6
# ...                                      ...
# 2895                                       7
# 2763                                       7
# 905                                        8
# 3980                                       6
# 235                                        6
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 1501                                    0                          0.000000
# 2704                                    0                          0.000000
# 4283                                    0                          0.000000
# 1288                                    4                         11.500000
# 137                                     6                         14.833333
# ...                                   ...                               ...
# 2895                                    6                         10.500000
# 2763                                    7                         13.285714
# 905                                     8                         12.550000
# 3980                                    6                         13.333333
# 235                                     6                         13.000000
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 1501                                               0               10.8
# 2704                                               0                7.6
# 4283                                               0               10.8
# 1288                                               0                7.6
# 137                                                0                8.9
# ...                                              ...                ...
# 2895                                               0               10.8
# 2763                                               0                7.6
# 905                                                0               12.4
# 3980                                               0               13.9
# 235                                                0               10.8
#
#       Inflation rate   GDP
# 1501             1.4  1.74
# 2704             2.6  0.32
# 4283             1.4  1.74
# 1288             2.6  0.32
# 137              1.4  3.51
# ...              ...   ...
# 2895             1.4  1.74
# 2763             2.6  0.32
# 905              0.5  1.79
# 3980            -0.3  0.79
# 235              1.4  1.74
#
# [3096 rows x 36 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
model=MinMaxScaler()
model.fit(x_train)
x_train=model.transform(x_train)
x_test=model.transform(x_test)
x_train
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.37209302, 0.48888889,
#         0.7661823 ],
#        [0.        , 0.28571429, 0.        , ..., 0.        , 0.75555556,
#         0.57859974],
#        [0.        , 0.67857143, 0.        , ..., 0.37209302, 0.48888889,
#         0.7661823 ],
#        ...,
#        [0.        , 0.        , 0.25      , ..., 0.55813953, 0.28888889,
#         0.77278732],
#        [0.        , 0.28571429, 0.625     , ..., 0.73255814, 0.11111111,
#         0.64068692],
#        [0.        , 0.        , 0.        , ..., 0.37209302, 0.48888889,
#         0.7661823 ]], shape=(3096, 36))

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['Dropout', 'Graduate', 'Graduate', ..., 'Dropout', 'Graduate',
#        'Graduate'], shape=(1328,), dtype=object)

# %%
y_test
# Out:
# 44       Dropout
# 3411    Graduate
# 4212    Graduate
# 3037    Graduate
# 1672     Dropout
#           ...
# 3455    Graduate
# 3925    Enrolled
# 3823     Dropout
# 1396    Enrolled
# 1677    Graduate
# Name: target, Length: 1328, dtype: object

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[293,  41,  72],
#        [ 35,  57, 149],
#        [ 16,  12, 653]])

# %%
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.7552710843373494

# %%
from sklearn.metrics import ConfusionMatrixDisplay
lab=['Dropout','Graduate','Enrolled']
cmd=ConfusionMatrixDisplay(cm,display_labels=lab)
cmd.plot()
